# %%
import argparse
import re
import pandas as pd

# parser = argparse.ArgumentParser()
# parser.add_argument("--infile", "-i", type=str, help="CSV for dataset to expand",
#                     required=True)
# args = parser.parse_args()

csvs=["change.org_topic_0.csv","change.org_topic_1.csv","change.org_topic_2.csv","change.org_topic_3.csv","change.org_topic_4.csv"]
for csv in csvs:    
    for topic in ["lockdowns", "masking and distancing", "vaccination","missing"]:
        df = pd.read_csv(csv)
        cols = df.columns
        for col in cols:
            if "annotation" in col:
                df[col] = (df[col].notna() & df[col].str.contains(topic))
        new_fn = re.sub(r"\.csv$", f"_{topic.replace(' ', '_')}.csv", csv)
        df.to_csv(new_fn, index=False)

# %%
# PART 1
# PART 1
# PART 1

# 1,2 done
# 3. renamed all missing rows with "missing" & loading csv file from dataframe
import pandas as pd
from collections import Counter
from sklearn.metrics import cohen_kappa_score
import csv

# list of labels created
labels = ["lockdowns", "masking_and_distancing", "vaccination"]

# insitialising final dictionary output 
final_labels = {"lockdowns": {"text":"label"},"masking_and_distancing": {"text":"label"},"vaccination": {"text":"label"}}
# inistilaizong final dic object
accum_labels={"text":"label"}

# iterrating given 5 files of change.org_topic
for i in range(0,5):
    for label in labels:
        # reading csv
        df = pd.read_csv('change.org_topic_'+str(i)+'_' + label + '.csv', skiprows=0)
        # checking the df row length and generating kappa score
        if df.shape[1]==5:
            df.columns = ["text", "an1", "an2", "an3", "an4"]
            # using sklearn cohen_kappa_score
            kappa_an_1_2 = cohen_kappa_score(df["an1"], df["an2"])
            kappa_an_1_3 = cohen_kappa_score(df["an1"], df["an3"])
            kappa_an_1_4 = cohen_kappa_score(df["an1"], df["an4"])
            kappa_an_2_3 = cohen_kappa_score(df["an2"], df["an3"])
            kappa_an_2_4 = cohen_kappa_score(df["an2"], df["an4"])
            kappa_an_3_4 = cohen_kappa_score(df["an3"], df["an4"])

            annotators = {}
            # taking mean of the kappa score
            annotators["an1"] = (kappa_an_1_2 + kappa_an_1_3 + kappa_an_1_4) / 3
            annotators["an2"] = (kappa_an_1_2 + kappa_an_2_3 + kappa_an_2_4) / 3
            annotators["an3"] = (kappa_an_1_3 + kappa_an_2_3 + kappa_an_3_4) / 3
            annotators["an4"] = (kappa_an_1_4 + kappa_an_2_4 + kappa_an_3_4) / 3
        else:
            # using sklearn cohen_kappa_score
            df.columns = ["text", "an1", "an2", "an3", "an4","an5"]
            kappa_an_1_2 = cohen_kappa_score(df["an1"], df["an2"])
            kappa_an_1_3 = cohen_kappa_score(df["an1"], df["an3"])
            kappa_an_1_4 = cohen_kappa_score(df["an1"], df["an4"])
            kappa_an_1_5 = cohen_kappa_score(df["an1"], df["an5"])
            kappa_an_2_3 = cohen_kappa_score(df["an2"], df["an3"])
            kappa_an_2_4 = cohen_kappa_score(df["an2"], df["an4"])
            kappa_an_2_5 = cohen_kappa_score(df["an2"], df["an5"])
            kappa_an_3_4 = cohen_kappa_score(df["an3"], df["an4"])
            kappa_an_3_5 = cohen_kappa_score(df["an3"], df["an5"])
            kappa_an_4_5 = cohen_kappa_score(df["an4"], df["an5"])
            annotators = {}
            # taking mean of the kappa score
            annotators["an1"] = (kappa_an_1_2 + kappa_an_1_3 + kappa_an_1_4 + kappa_an_1_5) / 4
            annotators["an2"] = (kappa_an_1_2 + kappa_an_2_3 + kappa_an_2_4 + kappa_an_2_5) / 4
            annotators["an3"] = (kappa_an_1_3 + kappa_an_2_3 + kappa_an_3_4 + kappa_an_3_5) / 4
            annotators["an4"] = (kappa_an_1_4 + kappa_an_2_4 + kappa_an_3_4 + kappa_an_4_5) / 4
            annotators["an5"] = (kappa_an_1_5 + kappa_an_2_5 + kappa_an_3_5 + kappa_an_4_5) / 4
            
            
# PART TWO
# PART TWO
# PART TWO

        print("\nchange org topic -",i,"file label", label, ":" ,str(annotators))
        
        
        # 1. eliminate any labels for annotators whose average kappa score is less than 0.2 (unreliable annotators)
        delItems = []
        for key, value in annotators.items():
            if value<0.2:
                delItems.append(key)
        for j in delItems:
            del annotators[j]
            df = df.drop(j, 1)
            
        print("\n")
        print("after delete minimum annotators", annotators)
        print("\n")
        
        # logic to generate the key value pairs for csv
        for index, row in df.iterrows():
            count = Counter(row[1:]).most_common(1)
            if count == 1:
                # 3. If there are ties (the same number of annotators for different labels), use the label with higher-reliability annotators (higher kappa scores on average)
                v = row[max(annotators, key=annotators.get)]
                try:
                    values = accum_labels[row[0]]
                except KeyError:
                    accum_labels[row[0]] = []
                accum_labels[row[0]].append(label)
                final_labels[v][row[0]]= v
            else:
                # 2. assign the final label to each text as the most frequent label among the remainiing annotators
                try:
                    values = accum_labels[row[0]]
                except KeyError:
                    accum_labels[row[0]] = []
                if count[0][0] is True:
                    accum_labels[row[0]].append(label)
                    final_labels[label][row[0]]= count[0][0]
                else:
                    final_labels[label][row[0]]= count[0][0]
        print('----------------------------End of file',i,'------------------------------------')
# Out:
# change org topic - 0 file label lockdowns : {'an1': 0.3767783800795567, 'an2': 0.03769865669786676, 'an3': 0.3456977184019719, 'an4': 0.4282583348403162, 'an5': 0.4248114868097386}
#
#
# after delete minimum annotators {'an1': 0.3767783800795567, 'an3': 0.3456977184019719, 'an4': 0.4282583348403162, 'an5': 0.4248114868097386}
#
#
# ----------------------------End of file 0 ------------------------------------
#
# change org topic - 0 file label masking_and_distancing : {'an1': 0.2014534965592872, 'an2': -0.0062417514317987255, 'an3': 0.13854987904274066, 'an4': 0.1933687369210724, 'an5': 0.2576172341374985}
#
#
# after delete minimum annotators {'an1': 0.2014534965592872, 'an5': 0.2576172341374985}
#
#
# ----------------------------End of file 0 ------------------------------------
#
# change org topic - 0 file label vaccination : {'an1': 0.12217198608644952, 'an2': -0.005376101051554338, 'an3': 0.2621759843646737, 'an4': 0.2509715151694918, 'an5': 0.13697043678091242}
#
#
# after delete minimum annotators {'an3': 0.2621759843646737, 'an4': 0.2509715151694918}
#
#
# ----------------------------End of file 0 ------------------------------------
#
# change org topic - 1 file label lockdowns : {'an1': 0.39364100293054943, 'an2': 0.46609505372517274, 'an3': 0.35665361565697995, 'an4': 0.30649557663999455}
#
#
# after delete minimum annotators {'an1': 0.39364100293054943, 'an2': 0.46609505372517274, 'an3': 0.35665361565697995, 'an4': 0.30649557663999455}
#
#
# ----------------------------End of file 1 ------------------------------------
#
# change org topic - 1 file label masking_and_distancing : {'an1': 0.3271023526433893, 'an2': 0.24974818844627159, 'an3': 0.2965985925198738, 'an4': 0.21345848907986684}
#
#
# after delete minimum annotators {'an1': 0.3271023526433893, 'an2': 0.24974818844627159, 'an3': 0.2965985925198738, 'an4': 0.21345848907986684}
#
#
# ----------------------------End of file 1 ------------------------------------
#
# change org topic - 1 file label vaccination : {'an1': 0.4071067270825585, 'an2': 0.41143158404552654, 'an3': 0.33597392235776047, 'an4': 0.15714412525374102}
#
#
# after delete minimum annotators {'an1': 0.4071067270825585, 'an2': 0.41143158404552654, 'an3': 0.33597392235776047}
#
#
# ----------------------------End of file 1 ------------------------------------
#
# change org topic - 2 file label lockdowns : {'an1': 0.622806139472806, 'an2': 0.6427222846004447, 'an3': 0.47905378802347115, 'an4': 0.6476747126970107}
#
#
# after delete minimum annotators {'an1': 0.622806139472806, 'an2': 0.6427222846004447, 'an3': 0.47905378802347115, 'an4': 0.6476747126970107}
#
#
# ----------------------------End of file 2 ------------------------------------
#
# change org topic - 2 file label masking_and_distancing : {'an1': 0.20377207915199477, 'an2': 0.22058691129610516, 'an3': 0.0, 'an4': 0.19804460560689363}
#
#
# after delete minimum annotators {'an1': 0.20377207915199477, 'an2': 0.22058691129610516}
#
#
# ----------------------------End of file 2 ------------------------------------
#
# change org topic - 2 file label vaccination : {'an1': 0.6519690422129448, 'an2': 0.7854252367909931, 'an3': 0.5834154561380728, 'an4': 0.7501466670105877}
#
#
# after delete minimum annotators {'an1': 0.6519690422129448, 'an2': 0.7854252367909931, 'an3': 0.5834154561380728, 'an4': 0.7501466670105877}
#
#
# ----------------------------End of file 2 ------------------------------------
#
# change org topic - 3 file label lockdowns : {'an1': 0.4200460114235917, 'an2': 0.4371382830557451, 'an3': 0.45454008844232313, 'an4': 0.43423711832993034}
#
#
# after delete minimum annotators {'an1': 0.4200460114235917, 'an2': 0.4371382830557451, 'an3': 0.45454008844232313, 'an4': 0.43423711832993034}
#
#
# ----------------------------End of file 3 ------------------------------------
#
# change org topic - 3 file label masking_and_distancing : {'an1': 0.3646427764050817, 'an2': 0.49366428625005804, 'an3': 0.4672559392890074, 'an4': 0.4033470237744203}
#
#
# after delete minimum annotators {'an1': 0.3646427764050817, 'an2': 0.49366428625005804, 'an3': 0.4672559392890074, 'an4': 0.4033470237744203}
#
#
# ----------------------------End of file 3 ------------------------------------
#
# change org topic - 3 file label vaccination : {'an1': 0.3876597393675265, 'an2': 0.6049309337905934, 'an3': 0.5622891963427569, 'an4': 0.5241054451580767}
#
#
# after delete minimum annotators {'an1': 0.3876597393675265, 'an2': 0.6049309337905934, 'an3': 0.5622891963427569, 'an4': 0.5241054451580767}
#
#
# ----------------------------End of file 3 ------------------------------------
#
# change org topic - 4 file label lockdowns : {'an1': 0.09472345790245129, 'an2': 0.36010628808917683, 'an3': 0.38002727513320894, 'an4': 0.38613193821237113}
#
#
# after delete minimum annotators {'an2': 0.36010628808917683, 'an3': 0.38002727513320894, 'an4': 0.38613193821237113}
#
#
# ----------------------------End of file 4 ------------------------------------
#
# change org topic - 4 file label masking_and_distancing : {'an1': 0.2050467381297456, 'an2': 0.3750365569505501, 'an3': 0.4517290066893758, 'an4': 0.38693576068206964}
#
#
# after delete minimum annotators {'an1': 0.2050467381297456, 'an2': 0.3750365569505501, 'an3': 0.4517290066893758, 'an4': 0.38693576068206964}
#
#
# ----------------------------End of file 4 ------------------------------------
#
# change org topic - 4 file label vaccination : {'an1': 0.5267395021958605, 'an2': 0.7344262383224409, 'an3': 0.751427803587239, 'an4': 0.6674261993660947}
#
#
# after delete minimum annotators {'an1': 0.5267395021958605, 'an2': 0.7344262383224409, 'an3': 0.751427803587239, 'an4': 0.6674261993660947}
#
#
# ----------------------------End of file 4 ------------------------------------

# %%
# Combining all of the text/label pairs for the PRIMARY dataset into a single CSV file, with the columns "text" and "label"
labels = ["lockdowns", "masking_and_distancing", "vaccination"]
for label in labels:
    with open('change.org_topic_'+label+'.csv', 'w') as f:
        writer = csv.writer(f)
        for row in final_labels[label].items():
            writer.writerow(row)

# %%
# generating overall file with key as text and values as list of annotations
with open('change.org_topic_final_label.csv', 'w') as f:
    writer = csv.writer(f)
    for row in accum_labels.items():
        writer.writerow(row)
